# %%
import yaml
with open('./engine_config.yaml', 'r', encoding='utf-8') as file:
    prime_service = yaml.safe_load(file)

# %%
print(prime_service['GOOGLE_ASR']["PROJECT_ID"])
# Out:
# gen-ai-demo-3-433812

# %%
! gcloud auth application-default login
# Out:
# 'gcloud' is not recognized as an internal or external command,
# operable program or batch file.

# %%
! gcloud init
# Out:
# 'gcloud' is not recognized as an internal or external command,
# operable program or batch file.

# %%
! gcloud auth application-default login
# Out:
# 'gcloud' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from anthropic import AnthropicVertex
model = AnthropicVertex(project_id="gen-ai-demo-3",
                                     region="us-east5")

# %%
model

# %%
from anthropic import AnthropicVertex

project_id = "gen-ai-demo-3-433812" # replace this with your project ID
region = "us-east5"  # Two region for Sonnet 3.5 ["us-east5", "europe-west1"]

client = AnthropicVertex(project_id=project_id, region=region)
response = ""
with client.messages.stream(
  max_tokens=1024,
  messages=[
    {
      "role": "user",
      "content": "บอกสูตรทำขนมปังกล้วยหน่อยครับ.",
    }
  ],
  model="claude-3-haiku@20240307",
) as stream:
  for text in stream.text_stream:
    print(text)
    response += text
# Out:
# ขน
# มปังก
# ล้วย
#  เ
# ป็นข
# นมป
# ังที
# ่มีก
# ล้วย
# เ
# ป็นส
# ่วนผ
# สมหล
# ัก ม
# ีส
# ู
# ตรและ
# ว
# ิธีการ
# ทำด
# ังนี้
# :
#
#
# ส
# ่วนผ
# สม
# :
# - แ
# ป
# ้ง
# ส
# า
# ล
# ีข
# น
# มปั
# ง 300
#  กรั
# ม
# - ก
# ล้วย
# น
# ้
# ำว
# ้าส
# ุ
# ก 300
# กรัม
#  (
# ประ
# มาณ
#  3
# -4
#
# ล
# ู
# ก)
# -
#  น
# ้ำต
# าลท
# ราย 50
#  กรั
# ม
# - เ
# ก
# ลือ
# 1
# /
# 4 ช
# ้อนช
# า
# - น
# มสด
#  150
#  ม
# ิ
# ลลิล
# ิตร
#
# - แป
# ้งสา
# ลี
# ส
# ำ
# หรับโ
# ร
# ยพ
# ื
# ้น
#
# - เ
# นย 50
#  กรั
# ม (
# ส
# ำหรับ
# ปั
# ย
# )
#
#
# วิธี
# ทำ:
#
# 1. บ
# ดก
# ล้วย
# ให้เป
# ็นเ
# น้ือ
# เ
# น
# ียนละเ
# อียด
#
# 2. ผ
# ส
# มแป้
# งสาล
# ี น
# ้ำต
# าล
#  และ
# เกลือ
# ในช
# า
# ม
#
# ก่อน
# เ
# ติมน
# มสดและ
# ก
# ล้วย
# ที
# ่บ
# ดแล้
# ว ค
# น
# ให
# ้เข้
# ากัน
#
# 3. น
# ว
# ดแ
# ป
# ้งจ
# นเป็
# นก
# ้
# อน
# เน
# ื
# ้อน
# ุ่
# ม
# ไม่เ
# ห
# นียว
# ม
# าก
# 4
# .
# ป
# ั้
# นก
# ้อนแ
# ป้งเ
# ป
# ็นก
# ้อนก
# ลม
#  ใ
# ส่
# ลงในถ
# า
# ด
# ที
# ่ร
# อง
# ด
# ...

# %%
response
# Out:
# 'ขนมปังกล้วย เป็นขนมปังที่มีกล้วยเป็นส่วนผสมหลัก มีสูตรและวิธีการทำดังนี้:\n\nส่วนผสม:\n- แป้งสาลีขนมปัง 300 กรัม\n- กล้วยน้ำว้าสุก 300 กรัม (ประมาณ 3-4 ลูก)\n- น้ำตาลทราย 50 กรัม\n- เกลือ 1/4 ช้อนชา\n- นมสด 150 มิลลิลิตร\n- แป้งสาลีสำหรับโรยพื้น\n- เนย 50 กรัม (สำหรับปัย)\n\nวิธีทำ:\n1. บดกล้วยให้เป็นเน้ือเนียนละเอียด\n2. ผสมแป้งสาลี น้ำตาล และเกลือในชาม ก่อนเติมนมสดและกล้วยที่บดแล้ว คนให้เข้ากัน\n3. นวดแป้งจนเป็นก้อนเนื้อนุ่ม ไม่เหนียวมาก\n4. ปั้นก้อนแป้งเป็นก้อนกลม ใส่ลงในถาดที่รองด้วยแป้งสาลี ปิดผ้าขึ้นพักให้แป้งพัฒนาตัวเป็นเวลา 30 นาที\n5. ค่อยๆ คลึงแป้งให้เป็นรูปทรงยาวแบน หรือตามชอบ แล้วมาวางลงในภาชนะรองอบ\n6. ทาเนยที่ผิวของขนมก่อนอบ\n7. อบที่อุณหภูมิ 180-200 องศาเซลเซียส ประมาณ 25-30 นาที จนสุกและเกิดสีน้ำตาล\n8. เมื่ออบเสร็จ ทิ้งให้เย็นก่อนนำออกจากถาด\n\nขนมปังกล้วยที่ทำได้จะมีเนื้อนุ่มและมีความหอมของกล้วยเล็กน้อย เป็นขนมที่อร่อยและง่ายต่อการทำ'

# %%
for i in iter("กล้วย เป็นขนมปังที่มีกล้วยเป็นส่วนผสมหลัก มีสูตรและวิธีการทำดังนี้:\n\nส่วนผสม:\n- แป้งสาลีขนมปัง 300 กรัม\n- กล้วยน้ำว้าสุก 300 กรัม (ประมาณ 3-4 ลูก)"):
    print(i)
    print("f")
# Out:
# ก
# f
# ล
# f
# ้
# f
# ว
# f
# ย
# f
#
# f
# เ
# f
# ป
# f
# ็
# f
# น
# f
# ข
# f
# น
# f
# ม
# f
# ป
# f
# ั
# f
# ง
# f
# ท
# f
# ี
# f
# ่
# f
# ม
# f
# ี
# f
# ก
# f
# ล
# f
# ้
# f
# ว
# f
# ย
# f
# เ
# f
# ป
# f
# ็
# f
# น
# f
# ส
# f
# ่
# f
# ว
# f
# น
# f
# ผ
# f
# ส
# f
# ม
# f
# ห
# f
# ล
# f
# ั
# f
# ก
# f
#
# f
# ม
# f
# ี
# f
# ส
# f
# ู
# f
# ต
# f
# ร
# f
# แ
# f
# ล
# f
# ะ
# f
# ว
# f
# ิ
# f
# ธ
# f
# ี
# f
# ก
# f
# า
# f
# ร
# f
# ท
# f
# ำ
# f
# ด
# f
# ั
# f
# ง
# f
# น
# f
# ี
# f
# ้
# f
# :
# f
#
#
# f
#
#
# f
# ส
# f
# ่
# f
# ว
# f
# น
# f
# ผ
# f
# ส
# f
# ม
# f
# :
# f
#
#
# f
# -
# f
#
# f
# แ
# f
# ป
# f
# ้
# f
# ง
# f
# ส
# f
# า
# f
# ล
# f
# ี
# f
# ข
# f
# น
# f
# ม
# f
# ป
# f
# ั
# f
# ง
# f
#
# f
# 3
# f
# 0
# f
# 0
# f
#
# f
# ก
# f
# ร
# f
# ั
# f
# ม
# f
#
#
# f
# -
# f
#
# f
# ก
# f
# ล
# f
# ้
# f
# ว
# f
# ย
# f
# น
# f
# ้
# f
# ำ
# f
# ว
# f
# ้
# f
# า
# f
# ส
# f
# ุ
# f
# ก
# f
#
# f
# 3
# f
# 0
# f
# 0
# f
#
# f
# ก
# f
# ร
# f
# ...

# %%
def test(**kwargs):
    print(kwargs["CLAUDE"]["MODEL_VERSION"])

test(**{'CLAUDE': {'MODEL_VERSION': None, 'PROJECT_ID': 'gen-ai-demo-3', 'REGION': 'us-east5'}})
# Out:
# None

# %%
import requests

def google_search(query: str, api_key: str, search_engine_id: str, num_results: int = 5):
    """
    Perform a Google search using the Custom Search JSON API.
    
    Parameters:
        query (str): The search query.
        api_key (str): Google API key.
        search_engine_id (str): Custom Search Engine (CSE) ID.
        num_results (int): Number of results to return (default is 5).
    
    Returns:
        list: A list of search results, each containing the title, link, and snippet.
    """
    search_url = "https://www.googleapis.com/customsearch/v1"
    params = {
        "key": api_key,
        "cx": search_engine_id,
        "q": query,
        "num": num_results
    }

    try:
        response = requests.get(search_url, params=params)
        response.raise_for_status()
        results = response.json().get("items", [])
        
        # Extract relevant information from each result
        search_results = []
        for item in results:
            result = {
                "title": item.get("title"),
                "link": item.get("link"),
                "snippet": item.get("snippet")
            }
            search_results.append(result)
            
        return search_results

    except requests.RequestException as e:
        print(f"An error occurred: {e}")
        return []

# %%
result = google_search(
    query="Manchester United next match schedule",
    api_key="AIzaSyB4kkGvooE_2-AF6DThyl0luTiM61_rb4A",
    search_engine_id="c7329772f516c4957",
)

# %%
result
# Out:
# [{'title': "Fixtures & Results | Man Utd Men's First Team | Manchester United",
#   'link': 'https://www.manutd.com/en/matches/fixtures-results',
#   'snippet': "Find fixtures and results for Manchester United men's first team on the official website, ManUtd.com."},
#  {'title': 'Manchester United 2024-25 Schedule - ESPN',
#   'link': 'https://www.espn.com/soccer/team/fixtures/_/id/360/manchester-united',
#   'snippet': '... all of your favorite sports! Scores. Manchester United. Follow. Home · Fixtures · Results · Squad · Stats · Transfers · Table. Manchester United Fixtures.'},
#  {'title': 'Manchester United Schedule & Fixtures - 2024-25 EPL Matches ...',
#   'link': 'https://www.nytimes.com/athletic/football/team/manchester-united/schedule/',
#   'snippet': 'Full 2024-25 Manchester United schedule. Scores, opponents, and dates of games for the entire season.'},
#  {'title': 'Manchester United Fixtures | Sky Sports',
# ...

# %%
from bs4 import BeautifulSoup

def fetch_web_content(url: str) -> str:
    try:
        # Fetch the HTML content
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Extract text based on known structure of the target page
        content = []
        
        # Customize these selectors as per the HTML structure
        # For example: main content within divs with a specific class
        for div in soup.find_all('div'):  # Adjust 'specific-content-class'
            content.append(div.get_text(separator=' ', strip=True))
    
        
        # Join all parts into a single string of text
        main_text = '\n'.join(content)
        return main_text if main_text else "No relevant content found."
    
    except requests.exceptions.RequestException as e:
        return f"Error fetching content: {e}"

# %%
url = 'https://football.kapook.com/%E0%B8%9E%E0%B8%A3%E0%B8%B5%E0%B9%80%E0%B8%A1%E0%B8%B5%E0%B8%A2%E0%B8%A3%E0%B9%8C%E0%B8%A5%E0%B8%B5%E0%B8%81'
content = fetch_web_content(result[0]["link"])
print(content)
# Out:
# Skip to Main Navigation Skip to content en 中文 日本語 한국어 العربية Español click to go to homepage Log In Open overlay Sign Up Open overlay Home News Latest back MUTV MUTV back Store Store back Fixtures Fixtures back Tickets & Hospitality Tickets back My United My United back Fans Fans back Players Players back Old Trafford Old Trafford back More More back English Expand or Collapse Website language 中文 日本語 한국어 العربية Español Latest Fixtures My United Players Search Men Log In Open overlay Sign Up Open overlay Download the App Accessibility Contact Us Jobs & Careers Privacy Cookies Terms Of Use Terms & Conditions of Sale Anti-slavery Help ©2024 Manchester United FC Ltd
#
#
# ...

# %%
import uuid
str(uuid.uuid4())
# Out:
# 'c0f9cc32-a8b3-46ea-a450-7ad3b206a5c2'

# %%
from langchain_core.tools import Tool
from langchain_google_community import GoogleSearchAPIWrapper

# %%
api_key="AIzaSyB4kkGvooE_2-AF6DThyl0luTiM61_rb4A",
    search_engine_id="c7329772f516c4957",

# %%
search = GoogleSearchAPIWrapper(google_api_key="AIzaSyB4kkGvooE_2-AF6DThyl0luTiM61_rb4A",google_cse_id="c7329772f516c4957")

tool = Tool(
    name="google_search",
    description="Search Google for recent results.",
    func=search.run,
)

# %%
print(tool.run("โค้ชใหม่เเมนยู"))
# Out:
# โค้ชใหม่แมนยู · หลังวืด "ทูเคิล" สื่อแฉ "แมนยูฯ" ยกหูหา 3 กุนซือดัง นั่งบังเหียนแทน "เทน ฮาก" · เทน ฮาก แย่แล้ว "แมนยูฯ" คุยกับ "กุนซือใหม่" เรียบร้อย ลุ้น "เซอร์จิม" แต่งตั้งแทน · ผีทางสะดวก "เชล ... สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ด (อังกฤษ: Manchester United Football Club) เป็นสโมสรฟุตบอลตั้งอยู่ที่โอลด์แทรฟฟอร์ดในเกรเทอร์แมนเชสเตอร์ ประเทศอังกฤษ ... Oct 6, 2024 ... วันที่ 6 ตุลาคม 2567 ไอนิวส์ เว็บไซต์ข่าวฟุตบอลชื่อดังของอังกฤษ รายงานล่าสุดว่า แมนเชสเตอร์ ยูไนเต็ด สโมสรชั้นนำพรีเมียร์ลีก อังกฤษ เตรียมรื้อแผนเดินหน้าคว้าตัว โธมัส ทูเคิล มาเป็น ... May 22, 2024 ... เอริค เทน ฮาก กุนซือทีม แมนฯ ยูไนเต็ด หมดสิทธิ์คุมทีมดังของ พรีเมียร์ลีก ในซีซั่นหน้าอย่างแน่นอนแล้วหลังสื่อลือกระฉ่อนว่า เซอร์ จิม แรตคลิฟฟ์ ... Jul 20, 2024 ... #แมนยู #เชลซี #โฟนตุง #เชอรี่สามโคก ... Kittokhunu Murneak and 271 others. 󰤥 272. 󰤦 37. 󰤧 11. Jirayu Singhapanit. คิดถึงพี่เชอร์รี่ครับ · โฟนตุง profile picture. Sep 4, 2024 ... สื่อรายงาน โธมัส ทูเคิล คือตัวเลือกอันดับหนึ่งในการเข้ามาทำหน้าที่กุนซือคนใหม่ของ แมนเ
# ...

# %%
def top5_results(query):
    return search.results(query, 5)


tool = Tool(
    name="Google Search Snippets",
    description="Search Google for recent results.",
    func=top5_results,
)

# %%
from google.cloud.speech_v2 import SpeechClient
from google.cloud.speech_v2.types import cloud_speech

# %%
PROJECT_ID = prime_service['GOOGLE_ASR']["PROJECT_ID"]

# %%
def quickstart_v2(audio_file: str) -> cloud_speech.RecognizeResponse:
    """Transcribe an audio file.
    Args:
        audio_file (str): Path to the local audio file to be transcribed.
    Returns:
        cloud_speech.RecognizeResponse: The response from the recognize request, containing
        the transcription results
    """
    # Reads a file as bytes
    with open(audio_file, "rb") as f:
        audio_content = f.read()

    # Instantiates a client
    client = SpeechClient()

    config = cloud_speech.RecognitionConfig(
        auto_decoding_config=cloud_speech.AutoDetectDecodingConfig(),
        language_codes=["en-US"],
        model="long",
    )

    request = cloud_speech.RecognizeRequest(
        recognizer=f"projects/{PROJECT_ID}/locations/global/recognizers/_",
        config=config,
        content=audio_content,
    )

    # Transcribes the audio into text
    response = client.recognize(request=request)

    for result in response.results:
        print(f"Transcript: {result.alternatives[0].transcript}")

    return response

# %%
quickstart_v2("./ford/voices/1a96d2ce-eb94-40e6-aeeb-33a5a877c436.mp3")
# Out:
# Transcript: hello I'm an AI assistant created by anthropic to be helpful harmless and honest I don't actually teach any specific courses but I'd be happy to try to help you with general questions about Python Programming if you have any how can I assist you today
# metadata {
#   total_billed_duration {
#     seconds: 16
#   }
#   request_id: "67ac2edb-0000-2cda-b8c2-883d24f3f290"
# }
# results {
#   alternatives {
#     transcript: "hello I\'m an AI assistant created by anthropic to be helpful harmless and honest I don\'t actually teach any specific courses but I\'d be happy to try to help you with general questions about Python Programming if you have any how can I assist you today"
#     confidence: 0.982826233
#   }
#   result_end_offset {
#     seconds: 15
#     nanos: 480000000
#   }
#   language_code: "en-US"
# }
